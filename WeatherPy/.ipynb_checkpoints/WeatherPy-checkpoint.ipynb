# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Key Findings
# - In the northern hemisphere, there is a strong negative correlation between latitude and average max temperatures but there is more variance in the data the higher in latitude you observe. In other words, as you go from 0 (equator) to 90, the correlation between latitude and max temp has a r value of -.84
# - In the southern hemisphere, there is a positive correlation between latitude and max temp but not as strong as the correlation one would see in the northern half, with an r value of .51.
# - Wind and cloud conditions aren't significantly correlated with latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv

# Imported additional dependencies (to read json files, to create stat outputs, and print formatting)
import json
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1800)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1800)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 668

# %%
# Test URL
pprint(requests.get(url).json())
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -0.6136, 'lon': -47.3561},
#  'dt': 1611111472,
#  'id': 3389822,
#  'main': {'feels_like': 82.26,
#           'grnd_level': 1011,
#           'humidity': 85,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 78.57,
#           'temp_max': 78.57,
#           'temp_min': 78.57},
#  'name': 'Salinópolis',
#  'sys': {'country': 'BR', 'sunrise': 1611047735, 'sunset': 1611091468},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65, 'speed': 10.47}}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Creating list to hold all cities 
city_weather = []

print ("Beginning Data Retrieval")
print("--------------------------")

# Set increments by one once it reaches 50 or once it's out of cities to report back
rcd = 0
sets = 1
for city in cities:
    rcd += 1
  
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        sets += 1
        rcd = 0
    
    try:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
        response = requests.get(url).json()
        city_weather.append({
            'City':city,
            'Lat': response['coord']['lat'],
            'Long': response['coord']['lon'],
            'Max Temp': response['main']['temp_max'],
            'Humidity': response['main']['humidity'],
            'Wind': response['wind']['speed'],
            'Cloudiness': response['clouds']['all'],
            'Country': response['sys']['country'],
            'Date': response['dt']
        })
    except:
        print('City not found. Skipping...')
        pass                        

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | vestmannaeyjar
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | corinto
# Processing Record 7 of Set 1 | sur
# Processing Record 8 of Set 1 | benxi
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | isiolo
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | asau
# Processing Record 13 of Set 1 | gorontalo
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | margate
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | parry sound
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | sechura
# Processing Record 20 of Set 1 | umm lajj
# Processing Record 21 of Set 1 | gat
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | lons-le-saunier
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | grindavik
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | lazaro cardenas
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | shu
# Processing Record 31 of Set 1 | olga
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | dingle
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | kautokeino
# Processing Record 37 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 1 | mackay
# Processing Record 39 of Set 1 | bundu
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | vagur
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | kavieng
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | sanchor
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 
of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | vostok
# Processing Record 11 of Set 5 | giddalur
# Processing Record 12 of Set 5 | hua hin
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | bahia honda
# Processing Record 15 of Set 5 | timmins
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | erzin
# Processing Record 18 of Set 5 | xinyu
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | changtu
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | mehamn
# Processing Record 23 of Set 5 | jensen beach
# Processing Record 24 of Set 5 | provideniya
# Processing Record 25 of Set 5 | port hardy
# Processing Record 26 of Set 5 | sompeta
# Processing Record 27 of Set 5 | mattawa
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | dongsheng
# Processing Record 30 of Set 5 | kamenka
# Processing Record 31 of Set 5 | grand-santi
# Processing Record 32 of Set 5 | pacatuba
# Processing Record 33 of Set 5 | baracoa
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | kupang
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | norfolk
# Processing Record 38 of Set 5 | kikwit
# Processing Record 39 of Set 5 | raudeberg
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | lompoc
# Processing Record 43 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 5 | hervey bay
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | bokoro
# Processing Record 47 of Set 5 | pathein
# Processing Record 48 of Set 5 | abu dhabi
# Processing Record 49 of Set 5 | manjacaze
# Processing Record 50 of Set 5 | salinas
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | saint-augustin
# Processing Record 3 of Set 6 | socorro
# Processing Record 4 of Set 6 | garanhuns
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | awjilah
# Processing Record 8 of Set 6 | acapulco
# Processing Record 9 of Set 6 | ngaoundere
# Processing Record 10 of Set 6 | santa vitoria do palmar
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | fushan
# Processing Record 13 of Set 6 | el vigia
# Processing Record 14 of Set 6 | port hedland
# Processing Record 15 of Set 6 | martvili
# Processing Record 16 of Set 6 | oltu
# Processing Record 17 of Set 6 | berlevag
# Processing Record 18 of Set 6 | arman
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | kavaratti
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | skibotn
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | bandar
# Processing Record 25 of Set 6 | vanersborg
# Processing Record 26 of Set 6 | eyl
# Processing Record 27 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 6 | maniitsoq
# Processing Record 29 of Set 6 | nicoya
# Processing Record 30 of Set 6 | praia
# Processing Record 31 of Set 6 | saskylakh
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | sakaiminato
# Processing Record 35 of Set 6 | yeniseysk
# Processing Record 36 of Set 6 | arraial do cabo
# Processing Record 37 of Set 6 | darnah
# Processing Record 38 of Set 6 | bandarbeyla
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | dunedin
# Processing Record 41 of Set 6 | pedra azul
# Processing Record 42 of Set 6 | rocha
# Processing Record 43 of Set 6 | eten
# Processing Record 44 of Set 6 | usinsk
# Processing Record 45 of Set 6 | barcelos
# Processing Record 46 of Set 6 | torbay
# Processing Record 47 of Set 6 | genhe
# Processing Record 48 of Set 6 | chulym
# Processing Record 49 of Set 6 | tonota
# Processing Record 50 of Set 6 | tuktoyaktuk
# Processing Record 1 of Set 7 | ostrovnoy
# Processing Record 2 of Set 7 | dargaville
# Processing Record 3 of Set 7 | ribeira do pombal
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | tateyama
# Processing Record 6 of Set 7 | lewistown
# Processing Record 7 of Set 7 | road town
# Processing Record 8 of Set 7 | inverell
# Processing Record 9 of Set 7 | ponta do sol
# Processing Record 10 of Set 7 | santa rosa
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | nuevo progreso
# Processing Record 13 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 7 | west wendover
# Processing Record 15 of Set 7 | raymondville
# Processing Record 16 of Set 7 | vila do maio
# Processing Record 17 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 7 | soyo
# Processing Record 19 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 7 | ilulissat
# Processing Record 21 of Set 7 | fredericksburg
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | jevargi
# Processing Record 25 of Set 7 | sulphur
# Processing Record 26 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | upernavik
# Processing Record 30 of Set 7 | mariinsk
# Processing Record 31 of Set 7 | xichang
# Processing Record 32 of Set 7 | biak
# Processing Record 33 of Set 7 | qui nhon
# Processing Record 34 of Set 7 | chongwe
# Processing Record 35 of Set 7 | honiara
# Processing Record 36 of Set 7 | diffa
# Processing Record 37 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 7 | montepuez
# Processing Record 39 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | takoradi
# Processing Record 41 of Set 7 | armilla
# Processing Record 42 of Set 7 | san cristobal
# Processing Record 43 of Set 7 | merauke
# Processing Record 44 of Set 7 | coquimbo
# Processing Record 45 of Set 7 | nuuk
# Processing Record 46 of Set 7 | zhuhai
# Processing Record 47 of Set 7 | sterling
# Processing Record 48 of Set 7 | qurayyat
# Processing Record 49 of Set 7 | laela
# Processing Record 50 of Set 7 | yenagoa
# Processing Record 1 of Set 8 | ballina
# Processing Record 2 of Set 8 | mar del plata
# Processing Record 3 of Set 8 | tura
# Processing Record 4 of Set 8 | ocean city
# Processing Record 5 of Set 8 | mareeba
# Processing Record 6 of Set 8 | simeykyne
# Processing Record 7 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set
# Processing Record 37 of Set 9 | comodoro rivadavia
# Processing Record 38 of Set 9 | kailua
# Processing Record 39 of Set 9 | guerrero negro
# Processing Record 40 of Set 9 | nosy varika
# Processing Record 41 of Set 9 | boma
# Processing Record 42 of Set 9 | carauari
# Processing Record 43 of Set 9 | garlasco
# Processing Record 44 of Set 9 | qaqortoq
# Processing Record 45 of Set 9 | lata
# Processing Record 46 of Set 9 | taseyevo
# Processing Record 47 of Set 9 | liuzhou
# Processing Record 48 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 9 | rapid valley
# Processing Record 50 of Set 9 | gidam
# Processing Record 1 of Set 10 | argelia
# Processing Record 2 of Set 10 | penzance
# Processing Record 3 of Set 10 | stornoway
# Processing Record 4 of Set 10 | tinskoy
# Processing Record 5 of Set 10 | horodnytsya
# Processing Record 6 of Set 10 | tambau
# Processing Record 7 of Set 10 | jardim
# Processing Record 8 of Set 10 | kurilsk
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | micheweni
# Processing Record 11 of Set 10 | teguise
# Processing Record 12 of Set 10 | iwade
# Processing Record 13 of Set 10 | spassk-ryazanskiy
# Processing Record 14 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 10 | saint-georges
# Processing Record 16 of Set 10 | sabzevar
# Processing Record 17 of Set 10 | forestville
# Processing Record 18 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 10 | puerto gaitan
# Processing Record 22 of Set 10 | doctor arroyo
# Processing Record 23 of Set 10 | beisfjord
# Processing Record 24 of Set 10 | pochutla
# Processing Record 25 of Set 10 | dudinka
# Processing Record 26 of Set 10 | lima
# Processing Record 27 of Set 10 | shakawe
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | passo fundo
# Processing Record 30 of Set 10 | jumla
# Processing Record 31 of Set 10 | turmalina
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 10 | pokhara
# Processing Record 34 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 10 | gornopravdinsk
# Processing Record 36 of Set 10 | winslow
# Processing Record 37 of Set 10 | kosh-agach
# Processing Record 38 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 39 of Set 10 | jasper
# Processing Record 40 of Set 10 | port said
# Processing Record 41 of Set 10 | ust-tsilma
# Processing Record 42 of Set 10 | naples
# Processing Record 43 of Set 10 | gagnoa
# Processing Record 44 of Set 10 | katobu
# Processing Record 45 of Set 10 | elko
# Processing Record 46 of Set 10 | srikakulam
# Processing Record 47 of Set 10 | jalu
# Processing Record 48 of Set 10 | mikkeli
# Processing Record 49 of Set 10 | esso
# Processing Record 50 of Set 10 | cayenne
# Processing Record 1 of Set 11 | buluang
# Processing Record 2 of Set 11 | hamina
# Processing Record 3 of Set 11 | cornwall
# Processing Record 4 of Set 11 | misawa
# Processing Record 5 of Set 11 | miri
# Processing Record 6 of Set 11 | son la
# Processing Record 7 of Set 11 | lobito
# Processing Record 8 of Set 11 | byron bay
# Processing Record 9 of Set 11 | tilichiki
# Processing Record 10 of Set 11 | mikun
# Processing Record 11 of Set 11 | zhangye
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | esil
# Processing Record 14 of Set 11 | morristown
# Processing Record 15 of Set 11 | skjervoy
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | debre birhan
# Processing Record 18 of Set 11 | swan hill
# Processing Record 19 of Set 11 | portland
# Processing Record 20 of Set 11 | misratah
# Processing Record 21 of Set 11 | porto nacional
# Processing Record 22 of Set 11 | faanui
# Processing Record 23 of Set 11 | praya
# Processing Record 24 of Set 11 | civitanova marche
# Processing Record 25 of Set 11 | camacari
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | piacabucu
# Processing Record 28 of Set 11 | savannah bight
# Processing Record 29 of Set 11 | hami
# Processing Record 30 of Set 11 | suluq
# Processing Record 31 of Set 11 | fairbanks
# Processing Record 32 of Set 11 | malkapur
# Processing Record 33 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 11 | port lincoln
# Processing Record 35 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 11 | staryy nadym
# Processing Record 37 of Set 11 | sokoni
# Processing Record 38 of Set 11 | ponte san nicolo
# Processing Record 39 of Set 11 | kedrovyy
# Processing Record 40 of Set 11 | port hawkesbury
# Processing Record 41 of Set 11 | ewa beach
# Processing Record 42 of Set 11 | kropotkin
# Processing Record 43 of Set 11 | kalianget
# Processing Record 44 of Set 11 | flin flon
# Processing Record 45 of Set 11 | grand-lahou
# Processing Record 46 of Set 11 | churapcha
# Processing Record 47 of Set 11 | nong kung si
# Processing Record 48 of Set 11 | beloha
# Processing Record 49 of Set 11 | puerto escondido
# Processing Record 50 of Set 11 | batagay
# Processing Record 1 of Set 12 | tazovskiy
# Processing Record 2 of Set 12 | sao desiderio
# Processing Record 3 of Set 12 | noumea
# Processing Record 4 of Set 12 | tymovskoye
# Processing Record 5 of Set 12 | ulladulla
# Processing Record 6 of Set 12 | kirakira
# Processing Record 7 of Set 12 | villazon
# Processing Record 8 of Set 12 | sorong
# Processing Record 9 of Set 12 | mikhaylovka
# Processing Record 10 of Set 12 | tabas
# Processing Record 11 of Set 12 | saint anthony
# Processing Record 12 of Set 12 | marrakesh
# Processing Record 13 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 14 of Set 12 | boca raton
# Processing Record 15 of Set 12 | batagay-alyta
# Processing Record 16 of Set 12 | namchi
# Processing Record 17 of Set 12 | tromso
# Processing Record 18 of Set 12 | araria
# Processing Record 19 of Set 12 | meulaboh
# Processing Record 20 of Set 12 | sao joaquim
# Processing Record 21 of Set 12 | palaiokhora
# City not found. Skipping...
# Processing Record 22 of Set 12 | leh
# Processing Record 23 of Set 12 | maniwaki
# Processing Record 24 of Set 12 | sibolga
# Processing Record 25 of Set 12 | towada
# Processing Record 26 of Set 12 | phalodi
# Processing Record 27 of Set 12 | clyde river
# Processing Record 28 of Set 12 | pravda
# Processing Record 29 of Set 12 | valdivia
# Processing Record 30 of Set 12 | rudnichnyy
# Processing Record 31 of Set 12 | ribas do rio pardo
# Processing Record 32 of Set 12 | kabanjahe
# Processing Record 33 of Set 12 | klyuchi
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | wazirabad
# Processing Record 36 of Set 12 | kichera
# Processing Record 37 of Set 12 | victoria
# Processing Record 38 of Set 12 | amalapuram
# Processing Record 39 of Set 12 | alytus
# Processing Record 40 of Set 12 | chifeng
# Processing Record 41 of Set 12 | aitape
# Processing Record 42 of Set 12 | ayan
# Processing Record 43 of Set 12 | melo
# Processing Record 44 of Set 12 | kharp
# Processing Record 45 of Set 12 | aswan
# Processing Record 46 of Set 12 | carberry
# Processing Record 47 of Set 12 | progreso
# Processing Record 48 of Set 12 | lerik
# Processing Record 49 of Set 12 | buenaventura
# Processing Record 50 of Set 12 | yakeshi
# Processing Record 1 of Set 13 | sungaipenuh
# Processing Record 2 of Set 13 | anqiu
# Processing Record 3 of Set 13 | whitehorse
# Processing Record 4 of Set 13 | yar-sale
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | okhotsk
# Processing Record 7 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 13 | pimenteiras
# Processing Record 10 of Set 13 | dali
# Processing Record 11 of Set 13 | vardo
# Processing Record 12 of Set 13 | atarra
# Processing Record 13 of Set 13 | deputatskiy
# Processing Record 14 of Set 13 | masvingo
# Processing Record 15 of Set 13 | uruzgan
# Processing Record 16 of Set 13 | denpasar
# Processing Record 17 of Set 13 | goderich
# Processing Record 18 of Set 13 | jagdalpur
# Processing Record 19 of Set 13 | kalevala
# Processing Record 20 of Set 13 | puliyur
# Processing Record 21 of Set 13 | poum
# Processing Record 22 of Set 13 | san luis
# Processing Record 23 of Set 13 | wald-michelbach
# Processing Record 24 of Set 13 | dukat
# Processing Record 25 of Set 13 | saint-marc
# Processing Record 26 of Set 13 | brates
# Processing Record 27 of Set 13 | robertsport
# Processing Record 28 of Set 13 | westport
# Processing Record 29 of Set 13 | cotonou
# Processing Record 30 of Set 13 | buin
# Processing Record 31 of Set 13 | samana
# Processing Record 32 of Set 13 | moba
# Processing Record 33 of Set 13 | orotukan
# Processing Record 34 of Set 13 | flinders
# Processing Record 35 of Set 13 | kenai
# Processing Record 36 of Set 13 | labuhan
# Processing Record 37 of Set 13 | port keats
# Processing Record 38 of Set 13 | am timan
# Processing Record 39 of Set 13 | osterburg
# Processing Record 40 of Set 13 | tukums
# Processing Record 41 of Set 13 | vaitape
# Processing Record 42 of Set 13 | vanavara
# Processing Record 43 of Set 13 | taiyuan
# Processing Record 44 of Set 13 | ust-maya
# Processing Record 45 of Set 13 | tsivilsk
# Processing Record 46 of Set 13 | nizwa
# Processing Record 47 of Set 13 | ternate
# Processing Record 48 of Set 13 | altay
# Processing Record 49 of Set 13 | ilo
# Processing Record 50 of Set 13 | jawhar
# Processing Record 1 of Set 14 | azul
# Processing Record 2 of Set 14 | pangnirtung
# Processing Record 3 of Set 14 | kaeo
# Processing Record 4 of Set 14 | hirara
# Processing Record 5 of Set 14 | mitu
# Processing Record 6 of Set 14 | santa maria
# Processing Record 7 of Set 14 | surt
# Processing Record 8 of Set 14 | kjustendil
# Processing Record 9 of Set 14 | luanda
# Processing Record 10 of Set 14 | novyye burasy
# Processing Record 11 of Set 14 | gua musang
# Processing Record 12 of Set 14 | caravelas
# Processing Record 13 of Set 14 | evensk
# Processing Record 14 of Set 14 | warragul
# Processing Record 15 of Set 14 | bintulu
# Processing Record 16 of Set 14 | olinda
# Processing Record 17 of Set 14 | zubtsov
# Processing Record 18 of Set 14 | mvuma
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 14 | chapais
# Processing Record 22 of Set 14 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create data frame to convert to CSV
city_df = pd.DataFrame(city_weather)
city_df.head()

# Export Dataframe into a .csv
city_df.to_csv('cities.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Create new dataframe to hold all cities with humidity over 100 and run test 
# to check if it has anything in it
city_df_humid = city_df.loc[city_df['Humidity']>100]
if city_df_humid.empty:
    print("No cities with humidity over 100")
# Out:
# No cities with humidity over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
outliers = city_df[city_df['Humidity']>city_df['Humidity'].mean() + 3 * city_df['Humidity'].std()]
if outliers.empty:
    print("No outliers in the humidity data.")
    
city_df.describe()
# Out:
# No outliers in the humidity data.
#               Lat        Long    Max Temp    Humidity        Wind  Cloudiness  \
# count  615.000000  615.000000  615.000000  615.000000  615.000000  615.000000
# mean    21.182988   22.164226   46.890764   73.552846    8.180260   54.271545
# std     32.998226   89.613338   33.290129   18.084854    5.918616   39.727116
# min    -54.800000 -175.200000  -51.990000   13.000000    0.470000    0.000000
# 25%     -6.339300  -54.675800   28.000000   64.000000    3.440000    9.000000
# 50%     26.150000   26.891000   57.850000   78.000000    6.910000   68.000000
# 75%     48.096550  100.393550   74.810000   87.000000   11.085000   94.000000
# max     78.218600  179.316700   87.800000  100.000000   34.520000  100.000000
#
#                Date
# count  6.150000e+02
# mean   1.611098e+09
# std    8.593910e+01
# min    1.611098e+09
# 25%    1.611098e+09
# 50%    1.611098e+09
# 75%    1.611098e+09
# max    1.611098e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Max Temp']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Blues', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Humidity']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Reds', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Humidity %')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Humidity Levels ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Cloudiness']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Greys', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Cloudiness ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Wind']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Purples', edgecolor='grey')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Wind')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Wind ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create two new dataframes for northern and southern hemispheres

north_hemisphere = (city_df.loc[city_df['Lat']>0])
south_hemisphere = (city_df.loc[city_df['Lat']<0])

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Max Temp"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Max Temp"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Max Temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -1.41x + 90.65
# The R value (i.e. Coefficient of Correlation) is: -0.8381844143097898
# The R squared value (i.e. Coefficient of Determination) is: 0.7025531123918455

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Max Temp"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Max Temp"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Max temperatures", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.32x + 79.98
# The R value (i.e. Coefficient of Correlation) is: 0.5105507097049707
# The R squared value (i.e. Coefficient of Determination) is: 0.2606620271802493

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Humidity"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Humidity"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Humidity (%)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.21x + 64.82
# The R value (i.e. Coefficient of Correlation) is: 0.22793566454861056
# The R squared value (i.e. Coefficient of Determination) is: 0.05195466717321672

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Humidity"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Humidity"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Humidity", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.6x + 87.11
# The R value (i.e. Coefficient of Correlation) is: 0.47999120289207414
# The R squared value (i.e. Coefficient of Determination) is: 0.2303915548537803

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Cloudiness"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Cloudiness"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(60,40),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Cloudiness %", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.48x + 35.54
# The R value (i.e. Coefficient of Correlation) is: 0.24328041098773617
# The R squared value (i.e. Coefficient of Determination) is: 0.059185358370361825

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Cloudiness"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Cloudiness"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Correlation of Latitude and Cloudiness % (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 1.28x + 81.25
# The R value (i.e. Coefficient of Correlation) is: 0.41435544611423797
# The R squared value (i.e. Coefficient of Determination) is: 0.17169043572452916

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Wind"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Wind"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.title("Northern Hemisphere: Correlation of Latitude and Wind (mph)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind (mhp)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.01x + 7.63
# The R value (i.e. Coefficient of Correlation) is: 0.03869899106707687
# The R squared value (i.e. Coefficient of Determination) is: 0.0014976119096096951

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Wind"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Wind"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.title("Southern Hemisphere: Correlation of Latitude and Wind Speed (mph)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -0.13x + 5.64
# The R value (i.e. Coefficient of Correlation) is: -0.3067195184893078
# The R squared value (i.e. Coefficient of Determination) is: 0.09407686302231281
