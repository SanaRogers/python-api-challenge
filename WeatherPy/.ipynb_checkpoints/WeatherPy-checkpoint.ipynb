# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv

# Imported additional dependencies (to read json files, to create stat outputs, and print formatting)
import json
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1800)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1800)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 711

# %%
# Test URL
pprint(requests.get(url).json())
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.2776, 'lon': 47.0659},
#  'dt': 1610793194,
#  'id': 508068,
#  'main': {'feels_like': -11.33,
#           'grnd_level': 993,
#           'humidity': 92,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 1.11,
#           'temp_max': 1.11,
#           'temp_min': 1.11},
#  'name': 'Podosinovets',
#  'sys': {'country': 'RU', 'sunrise': 1610775596, 'sunset': 1610799757},
#  'timezone': 10800,
#  'visibility': 4907,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 19, 'speed': 10.85}}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather = []

print ("Beginning Data Retrieval")
print("--------------------------")

rcd = 0
sets = 1
for city in cities:
    rcd += 1
  
    print(f'Processing Record {rcd} of Set {sets} | {city}')
    
    if rcd == 50:
        sets += 1
        rcd = 0
    
    try:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
        response = requests.get(url).json()
        city_weather.append({
            'City':city,
            'Lat': response['coord']['lat'],
            'Long': response['coord']['lon'],
            'Max Temp': response['main']['temp_max'],
            'Humidity': response['main']['humidity'],
            'Wind': response['wind']['speed'],
            'Cloudiness': response['clouds']['all'],
            'Country': response['sys']['country'],
            'Date': response['dt']
        })
    except:
        print('City not found. Skipping...')
        pass                        

print('-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | meulaboh
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | krasnyy tkach
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | maceio
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | tuatapere
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | cap malheureux
# Processing Record 13 of Set 1 | clarksdale
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | alyangula
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | thanh hoa
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | amapa
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | pontiac
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | shintomi
# Processing Record 29 of Set 1 | sinolon
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | gambela
# Processing Record 32 of Set 1 | lodwar
# Processing Record 33 of Set 1 | gushikawa
# Processing Record 34 of Set 1 | praia da vitoria
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | hokitika
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | tecpan
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | dalrymple
# Processing Record 47 of Set 1 | praia
# Processing Record 48 of Set 1 | barranca
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | kuching
# Processing Record 2 of Set 2 | melilla
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | arlington
# Processing Record 9 of Set 2 | mokrousovo
# Processing Record 10 of Set 2 | chara
# Processing Record 11 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | moree
# Processing Record 14 of Set 2 | rawson
# Processing Record 15 of Set 2 | vao
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | valley city
# Processing Record 18 of Set 2 | lorengau
# Processing Record 19 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 20 of Set
of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | benguela
# Processing Record 46 of Set 3 | olga
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | arua
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | piney green
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | champerico
# Processing Record 3 of Set 4 | snasa
# Processing Record 4 of Set 4 | puerto pinasco
# City not found. Skipping...
# Processing Record 5 of Set 4 | sechura
# Processing Record 6 of Set 4 | arlit
# Processing Record 7 of Set 4 | charagua
# Processing Record 8 of Set 4 | ninghai
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | alice springs
# Processing Record 11 of Set 4 | mamallapuram
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | launceston
# Processing Record 14 of Set 4 | cirpan
# City not found. Skipping...
# Processing Record 15 of Set 4 | mitu
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | george town
# Processing Record 18 of Set 4 | estrela
# Processing Record 19 of Set 4 | we
# City not found. Skipping...
# Processing Record 20 of Set 4 | ciawi
# Processing Record 21 of Set 4 | yashalta
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | lieksa
# Processing Record 25 of Set 4 | linjiang
# Processing Record 26 of Set 4 | bairiki
# Processing Record 27 of Set 4 | zhongxing
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | mana
# Processing Record 30 of Set 4 | paita
# Processing Record 31 of Set 4 | katherine
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 4 | caceres
# Processing Record 35 of Set 4 | sharqpur
# Processing Record 36 of Set 4 | chokurdakh
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 4 | ahuimanu
# Processing Record 40 of Set 4 | manokwari
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | nishihara
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | elizabeth city
# Processing Record 46 of Set 4 | ayorou
# Processing Record 47 of Set 4 | chlorakas
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | nevelsk
# Processing Record 50 of Set 4 | acapulco
# Processing Record 1 of Set 5 | sawtell
# Processing Record 2 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 5 | esperance
# Processing Record 4 of Set 5 | yeniseysk
# Processing Record 5 of Set 5 | nadym
# Processing Record 6 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 5 | miles city
# Processing Record 8 of Set 5 | severobaykalsk
# Processing Record 9 of Set 5 | srednekolymsk
# Processing Record 10 of Set 5 | dunedin
# Processing Record 11 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 5 | tabuk
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | cabedelo
# Processing Record 15 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto escondido
# Processing Record 17 of Set 5 | hay river
# Processing Record 18 of Set 5 | bolivar
# Processing Record 19 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 5 | hallingby
# City not found. Skipping...
# Processing Record 21 of Set 5 | moba
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | san carlos del zulia
# Processing Record 25 of Set 5 | celestun
# Processing Record 26 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 5 | banda aceh
# Processing Record 28 of Set 5 | kirkland lake
# Processing Record 29 of Set 5 | kismayo
# Processing Record 30 of Set 5 | padilla
# Processing Record 31 of Set 5 | sao jose da coroa grande
# Processing Record 32 of Set 5 | hofn
# Processing Record 33 of Set 5 | forrest city
# Processing Record 34 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 5 | poum
# Processing Record 36 of Set 5 | fort nelson
# Processing Record 37 of Set 5 | cockburn town
# Processing Record 38 of Set 5 | bathsheba
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | newport
# Processing Record 41 of Set 5 | havre-saint-pierre
# Processing Record 42 of Set 5 | biak
# Processing Record 43 of Set 5 | nhulunbuy
# Processing Record 44 of Set 5 | caidian
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | uruzgan
# Processing Record 47 of Set 5 | krasnoselkup
# Processing Record 48 of Set 5 | bontang
# Processing Record 49 of Set 5 | pitimbu
# Processing Record 50 of Set 5 | sheksna
# Processing Record 1 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 2 of Set 6 | zhangjiakou
# Processing Record 3 of Set 6 | arraial do cabo
# Processing Record 4 of Set 6 | port moresby
# Processing Record 5 of Set 6 | siguiri
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | solano
# Processing Record 8 of Set 6 | kushima
# Processing Record 9 of Set 6 | pisco
# Processing Record 10 of Set 6 | imeni poliny osipenko
# Processing Record 11 of Set 6 | qui nhon
# Processing Record 12 of Set 6 | matam
# Processing Record 13 of Set 6 | muslyumovo
# Processing Record 14 of Set 6 | ahipara
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | manzanillo
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | buxtehude
# Processing Record 20 of Set 6 | provideniya
# Processing Record 21 of Set 6 | sistranda
# Processing Record 22 of Set 6 | lukovetskiy
# Processing Record 23 of Set 6 | mucurapo
# Processing Record 24 of Set 6 | hasaki
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | podor
# Processing Record 28 of Set 6 | bani
# Processing Record 29 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 6 | hurghada
# Processing Record 31 of Set 6 | carbonia
# Processing Record 32 of Set 6 | havoysund
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | jamestown
# Processing Record 35 of Set 6 | los llanos de aridane
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | gap
# Processing Record 39 of Set 6 | coaldale
# Processing Record 40 of Set 6 | ilulissat
# Processing Record 41 of Set 6 | sharan
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | kalmunai
# Processing Record 44 of Set 6 | salvador
# Processing Record 45 of Set 6 | bayevo
# Processing Record 46 of Set 6 | genhe
# Processing Record 47 of Set 6 | la palma
# Processing Record 48 of Set 6 | mecca
# Processing Record 49 of Set 6 | lipin bor
# Processing Record 50 of Set 6 | disa
# Processing Record 1 of Set 7 | pacifica
# Processing Record 2 of Set 7 | yellowknife
# Processing Record 3 of Set 7 | oro valley
# Processing Record 4 of Set 7 | northam
# Processing Record 5 of Set 7 | himora
# City not found. Skipping...
# Processing Record 6 of Set 7 | kastamonu
of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 10 | latung
# Processing Record 15 of Set 10 | svetlogorsk
# Processing Record 16 of Set 10 | mahanoro
# Processing Record 17 of Set 10 | minab
# Processing Record 18 of Set 10 | guerrero negro
# Processing Record 19 of Set 10 | sinop
# Processing Record 20 of Set 10 | lebu
# Processing Record 21 of Set 10 | ravar
# Processing Record 22 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 10 | samarinda
# Processing Record 24 of Set 10 | baykit
# Processing Record 25 of Set 10 | ghugus
# Processing Record 26 of Set 10 | rio verde de mato grosso
# Processing Record 27 of Set 10 | chor
# Processing Record 28 of Set 10 | sarangani
# Processing Record 29 of Set 10 | tigil
# Processing Record 30 of Set 10 | mount isa
# Processing Record 31 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 10 | sao gabriel da cachoeira
# Processing Record 33 of Set 10 | srandakan
# Processing Record 34 of Set 10 | nchelenge
# Processing Record 35 of Set 10 | japura
# Processing Record 36 of Set 10 | tucurui
# Processing Record 37 of Set 10 | beloha
# Processing Record 38 of Set 10 | rio grande
# Processing Record 39 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 10 | owando
# Processing Record 41 of Set 10 | shetpe
# Processing Record 42 of Set 10 | ajdabiya
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | greenwood
# Processing Record 45 of Set 10 | luwuk
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | bilma
# Processing Record 48 of Set 10 | atar
# Processing Record 49 of Set 10 | skelleftea
# Processing Record 50 of Set 10 | skjervoy
# Processing Record 1 of Set 11 | tiruchchendur
# Processing Record 2 of Set 11 | fare
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | semme
# Processing Record 5 of Set 11 | zuwarah
# Processing Record 6 of Set 11 | san ramon
# Processing Record 7 of Set 11 | at-bashi
# Processing Record 8 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 11 | vestmannaeyjar
# Processing Record 10 of Set 11 | leo
# Processing Record 11 of Set 11 | hays
# Processing Record 12 of Set 11 | worland
# Processing Record 13 of Set 11 | tabou
# Processing Record 14 of Set 11 | orotukan
# Processing Record 15 of Set 11 | esso
# Processing Record 16 of Set 11 | itupiranga
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | zeya
# Processing Record 19 of Set 11 | bauchi
# Processing Record 20 of Set 11 | ferme-neuve
# Processing Record 21 of Set 11 | vanavara
# Processing Record 22 of Set 11 | humaita
# Processing Record 23 of Set 11 | maniitsoq
# Processing Record 24 of Set 11 | zvishavane
# Processing Record 25 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 26 of Set 11 | nanakuli
# Processing Record 27 of Set 11 | pietermaritzburg
# Processing Record 28 of Set 11 | zaranj
# Processing Record 29 of Set 11 | qostanay
# Processing Record 30 of Set 11 | portree
# Processing Record 31 of Set 11 | shadegan
# Processing Record 32 of Set 11 | puerto ayacucho
# Processing Record 33 of Set 11 | raudeberg
# Processing Record 34 of Set 11 | leh
# Processing Record 35 of Set 11 | casa nova
# Processing Record 36 of Set 11 | cambridge
# Processing Record 37 of Set 11 | kidal
# Processing Record 38 of Set 11 | tecoanapa
# Processing Record 39 of Set 11 | camopi
# Processing Record 40 of Set 11 | hervey bay
# Processing Record 41 of Set 11 | oshnaviyeh
# Processing Record 42 of Set 11 | eirunepe
# Processing Record 43 of Set 11 | palana
# Processing Record 44 of Set 11 | borovskoy
# Processing Record 45 of Set 11 | homer
# Processing Record 46 of Set 11 | goderich
# Processing Record 47 of Set 11 | sinjar
# Processing Record 48 of Set 11 | limon
# Processing Record 49 of Set 11 | concepcion del uruguay
# Processing Record 50 of Set 11 | saint anthony
# Processing Record 1 of Set 12 | katobu
# Processing Record 2 of Set 12 | beira
# Processing Record 3 of Set 12 | fomboni
# Processing Record 4 of Set 12 | kendari
# Processing Record 5 of Set 12 | ancud
# Processing Record 6 of Set 12 | ulaangom
# Processing Record 7 of Set 12 | dwarka
# Processing Record 8 of Set 12 | zhangye
# Processing Record 9 of Set 12 | eureka
# Processing Record 10 of Set 12 | rincon
# Processing Record 11 of Set 12 | fortuna
# Processing Record 12 of Set 12 | quang ngai
# Processing Record 13 of Set 12 | prince george
# Processing Record 14 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 12 | vicosa do ceara
# Processing Record 17 of Set 12 | verkhnevilyuysk
# Processing Record 18 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 12 | tegh
# Processing Record 20 of Set 12 | vorobyevka
# Processing Record 21 of Set 12 | la macarena
# Processing Record 22 of Set 12 | aklavik
# Processing Record 23 of Set 12 | ballina
# Processing Record 24 of Set 12 | khani
# Processing Record 25 of Set 12 | rocha
# Processing Record 26 of Set 12 | paamiut
# Processing Record 27 of Set 12 | gberia fotombu
# Processing Record 28 of Set 12 | sorland
# Processing Record 29 of Set 12 | urumqi
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | brewster
# Processing Record 32 of Set 12 | bayangol
# Processing Record 33 of Set 12 | namibe
# Processing Record 34 of Set 12 | ponca city
# Processing Record 35 of Set 12 | rudbar
# Processing Record 36 of Set 12 | bom jesus
# Processing Record 37 of Set 12 | macapa
# Processing Record 38 of Set 12 | ugoofaaru
# Processing Record 39 of Set 12 | athabasca
# Processing Record 40 of Set 12 | gurupa
# Processing Record 41 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 42 of Set 12 | kushiro
# Processing Record 43 of Set 12 | grosseto
# Processing Record 44 of Set 12 | kazanskoye
# Processing Record 45 of Set 12 | salto
# Processing Record 46 of Set 12 | gerede
# Processing Record 47 of Set 12 | sinnamary
# Processing Record 48 of Set 12 | linxia
# Processing Record 49 of Set 12 | portland
# Processing Record 50 of Set 12 | port hardy
# Processing Record 1 of Set 13 | mpika
# Processing Record 2 of Set 13 | fonte boa
# Processing Record 3 of Set 13 | burnie
# Processing Record 4 of Set 13 | olafsvik
# Processing Record 5 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | kargasok
# Processing Record 7 of Set 13 | sayyan
# Processing Record 8 of Set 13 | synya
# Processing Record 9 of Set 13 | cidreira
# Processing Record 10 of Set 13 | preobrazheniye
# Processing Record 11 of Set 13 | ullal
# Processing Record 12 of Set 13 | jiayuguan
# Processing Record 13 of Set 13 | pierre
# Processing Record 14 of Set 13 | sillod
# Processing Record 15 of Set 13 | keti bandar
# Processing Record 16 of Set 13 | kautokeino
# Processing Record 17 of Set 13 | altamont
# Processing Record 18 of Set 13 | karachi
# Processing Record 19 of Set 13 | santa cruz do rio pardo
# Processing Record 20 of Set 13 | korhogo
# Processing Record 21 of Set 13 | balta
# Processing Record 22 of Set 13 | karpuninskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | san cristobal
# Processing Record 24 of Set 13 | flin flon
# Processing Record 25 of Set 13 | acajutla
# Processing Record 26 of Set 13 | tilichiki
# Processing Record 27 of Set 13 | kudahuvadhoo
# Processing Record 28 of Set 13 | broome
# Processing Record 29 of Set 13 | aljezur
# Processing Record 30 of Set 13 | kodinsk
# Processing Record 31 of Set 13 | allada
# Processing Record 32 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 13 | bima
# Processing Record 34 of Set 13 | auki
# Processing Record 35 of Set 13 | muroto
# Processing Record 36 of Set 13 | palauig
# Processing Record 37 of Set 13 | muros
# Processing Record 38 of Set 13 | bowen
# Processing Record 39 of Set 13 | marsh harbour
# Processing Record 40 of Set 13 | santiago del estero
# Processing Record 41 of Set 13 | alexandria
# Processing Record 42 of Set 13 | pielesti
# Processing Record 43 of Set 13 | abnub
# Processing Record 44 of Set 13 | damaturu
# Processing Record 45 of Set 13 | dzerzhinsk
# Processing Record 46 of Set 13 | marsabit
# Processing Record 47 of Set 13 | phaltan
# Processing Record 48 of Set 13 | mazagao
# Processing Record 49 of Set 13 | gabu
# Processing Record 50 of Set 13 | davila
# Processing Record 1 of Set 14 | teya
# Processing Record 2 of Set 14 | quelimane
# Processing Record 3 of Set 14 | bahia honda
# Processing Record 4 of Set 14 | omboue
# Processing Record 5 of Set 14 | manggar
# Processing Record 6 of Set 14 | smirnykh
# Processing Record 7 of Set 14 | godfrey
# Processing Record 8 of Set 14 | nokaneng
# Processing Record 9 of Set 14 | impfondo
# Processing Record 10 of Set 14 | kemijarvi
# Processing Record 11 of Set 14 | nome
# Processing Record 12 of Set 14 | cayenne
# Processing Record 13 of Set 14 | san jose
# Processing Record 14 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 14 | ulkan
# Processing Record 17 of Set 14 | praya
# Processing Record 18 of Set 14 | uyuni
# Processing Record 19 of Set 14 | pilar
# Processing Record 20 of Set 14 | cantagallo
# Processing Record 21 of Set 14 | sangmelima
# Processing Record 22 of Set 14 | kabo
# Processing Record 23 of Set 14 | terrace bay
# Processing Record 24 of Set 14 | hailun
# Processing Record 25 of Set 14 | merauke
# Processing Record 26 of Set 14 | dumai
# Processing Record 27 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 14 | oussouye
# Processing Record 29 of Set 14 | hachinohe
# Processing Record 30 of Set 14 | adrar
# Processing Record 31 of Set 14 | central point
# Processing Record 32 of Set 14 | millinocket
# Processing Record 33 of Set 14 | lugasu de jos
# Processing Record 34 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 14 | narrabri
# Processing Record 37 of Set 14 | santa maria
# Processing Record 38 of Set 14 | shelburne
# Processing Record 39 of Set 14 | vilyuysk
# Processing Record 40 of Set 14 | pinawa
# Processing Record 41 of Set 14 | skibotn
# Processing Record 42 of Set 14 | kasongo-lunda
# Processing Record 43 of Set 14 | karla
# Processing Record 44 of Set 14 | uchaly
# Processing Record 45 of Set 14 | singaparna
# Processing Record 46 of Set 14 | guiyang
# Processing Record 47 of Set 14 | otradnoye
# Processing Record 48 of Set 14 | victoria point
# Processing Record 49 of Set 14 | selkirk
# Processing Record 50 of Set 14 | palmer
# Processing Record 1 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 15 | veselynove
# Processing Record 3 of Set 15 | sorong
# Processing Record 4 of Set 15 | lewisporte
# Processing Record 5 of Set 15 | dole
# Processing Record 6 of Set 15 | nioro
# Processing Record 7 of Set 15 | axim
# Processing Record 8 of Set 15 | ouadda
# Processing Record 9 of Set 15 | pundaguitan
# Processing Record 10 of Set 15 | selma
# Processing Record 11 of Set 15 | podosinovets
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_weather)
city_df.head()

# Export Dataframe into a .csv
# city_df.to_csv('WeatherPy'\output_data_file)
# Out:
#             City      Lat     Long  Max Temp  Humidity   Wind  Cloudiness  \
# 0       meulaboh   4.1363  96.1285     78.71        83   1.21          92
# 1       tasiilaq  65.6145 -37.6368     30.20        93  11.50          40
# 2         albany  42.6001 -73.9662     33.01        88   4.36         100
# 3  krasnyy tkach  55.4721  39.0802      5.00        78  13.42          90
# 4        ushuaia -54.8000 -68.3000     53.60        71   8.05          40
#
#   Country        Date
# 0      ID  1610796299
# 1      GL  1610796299
# 2      US  1610796004
# 3      RU  1610796299
# 4      AR  1610796082

# %%
city_df = pd.DataFrame(city_weather)
city_df.head()
# Out:
#             City      Lat     Long  Max Temp  Humidity   Wind  Cloudiness  \
# 0       meulaboh   4.1363  96.1285     78.71        83   1.21          92
# 1       tasiilaq  65.6145 -37.6368     30.20        93  11.50          40
# 2         albany  42.6001 -73.9662     33.01        88   4.36         100
# 3  krasnyy tkach  55.4721  39.0802      5.00        78  13.42          90
# 4        ushuaia -54.8000 -68.3000     53.60        71   8.05          40
#
#   Country        Date
# 0      ID  1610796299
# 1      GL  1610796299
# 2      US  1610796004
# 3      RU  1610796299
# 4      AR  1610796082

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
try: 
    print(city_df.loc[city_df['Humidity']>100])

except:
    print("No cities with humidty over 100")
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Wind, Cloudiness, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
outliers = city_df[city_df['Humidity']>city_df['Humidity'].mean() + 3 * city_df['Humidity'].std()]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Wind, Cloudiness, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Max Temp']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Blues', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Humidity']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Reds', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Humidity %')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Humidity Levels ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Cloudiness']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Greys', edgecolor='black')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Cloudiness ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the DataFrame comparing the column of 'Lat' to 'Max Temp'
x = city_df['Lat']
y = city_df['Wind']

# Set color to the value of 'Max Temp' and assign color based on the gradient scale of a colormap
plt.scatter(x, y, c=y, cmap='Purples', edgecolor='grey')

#Assign labels, title, and grid
plt.xlabel('Latitude')
plt.ylabel('Wind')

# Title calls on the import datetime dependency to populate current day
plt.title(f'City Latitude vs. Wind ({time.strftime("%x")})')
plt.grid()

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create two new dataframes for northern and southern hemispheres

north_hemisphere = (city_df.loc[city_df['Lat']>0])
south_hemisphere = (city_df.loc[city_df['Lat']<0])
# Out:
#          City      Lat      Long  Max Temp  Humidity  Wind  Cloudiness  \
# 4     ushuaia -54.8000  -68.3000     53.60        71  8.05          40
# 5     rikitea -23.1203 -134.9692     77.92        71  4.41          39
# 6      maceio  -9.6658  -35.7353     80.60        74  5.75          40
# 9   tuatapere -46.1333  167.6833     59.85        66  6.78          56
# 10  carnarvon -24.8667  113.6333     82.40        78  6.91           0
#
#    Country        Date
# 4       AR  1610796082
# 5       PF  1610796191
# 6       BR  1610796300
# 9       NZ  1610796301
# 10      AU  1610796302

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Max Temp"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Max Temp"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Correlation of Latitude and Max temperatures (Northern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -1.4x + 94.42
# The R value (i.e. Coefficient of Correlation) is: -0.8588975208314262
# The R squared value (i.e. Coefficient of Determination) is: 0.7377049512903703

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Max Temp"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Max Temp"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Correlation of Latitude and Max temperatures (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.44x + 83.65
# The R value (i.e. Coefficient of Correlation) is: 0.6119060541213124
# The R squared value (i.e. Coefficient of Determination) is: 0.37442901907031445

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Humidity"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Humidity"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Correlation of Latitude and Humidity (Northern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.52x + 52.83
# The R value (i.e. Coefficient of Correlation) is: 0.4378517165932501
# The R squared value (i.e. Coefficient of Determination) is: 0.19171412572365581

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Humidity"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Humidity"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Correlation of Latitude and Humidity (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.17x + 76.93
# The R value (i.e. Coefficient of Correlation) is: 0.13283466580781073
# The R squared value (i.e. Coefficient of Determination) is: 0.01764504844027276

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_hemisphere["Lat"],north_hemisphere["Cloudiness"])
regress_values = north_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(north_hemisphere["Lat"],north_hemisphere["Cloudiness"])
plt.plot(north_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(60,40),fontsize=15,color="red")
plt.title("Correlation of Latitude and Cloudiness % (Northern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.48x + 38.13
# The R value (i.e. Coefficient of Correlation) is: 0.2421531961455617
# The R squared value (i.e. Coefficient of Determination) is: 0.058638170403510874

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Cloudiness"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Cloudiness"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,60),fontsize=15,color="red")
plt.title("Correlation of Latitude and Cloudiness % (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.96x + 81.68
# The R value (i.e. Coefficient of Correlation) is: 0.37499407460232725
# The R squared value (i.e. Coefficient of Determination) is: 0.14062055598685577

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_hemisphere["Lat"],south_hemisphere["Wind"])
regress_values = south_hemisphere["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(south_hemisphere["Lat"],south_hemisphere["Wind"])
plt.plot(south_hemisphere["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.title("Correlation of Latitude and Wind Speed (mph) (Southern Hemisphere)", y=1.02, fontsize=18);
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = -0.09x + 5.87
# The R value (i.e. Coefficient of Correlation) is: -0.22632395966234087
# The R squared value (i.e. Coefficient of Determination) is: 0.0512225347172409
